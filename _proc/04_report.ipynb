# %% [raw]
# ---
# output-file: report.html
# title: Analyis Report examples
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Report)
# Out:
# ---
#
# [source](https://github.com/jwmatthews/kyma_poc/blob/main/kyma_poc/report.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### Report
#
# >      Report (path_to_report)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# Trying Report parsing

# %%
## CoolStuff Example
output_dir = './example/coolstuff-javaee'
path_to_report = '../data/example_reports/coolstuff-javaee/output.yaml'
report = Report(path_to_report)
r = report.get_report()
print(f"We have results from {len(r.keys())} RuleSet(s) in {path_to_report}\n")
report.write_markdown(output_dir)

## Konveyor example-1
output_dir = './example/konveyor-examples/example-1'
path_to_report = '../data/example_reports/konveyor-examples/example-1/output.yaml'
report = Report(path_to_report)
r = report.get_report()
print(f"\nWe have results from {len(r.keys())} RuleSet(s) in {path_to_report}\n")
report.write_markdown(output_dir)
# Out:
# We have results from 4 RuleSet(s) in ../data/example_reports/coolstuff-javaee/output.yaml
#
# Writing eap7/websphere to ./example/coolstuff-javaee/eap7_websphere.md
# Writing eap8/eap7 to ./example/coolstuff-javaee/eap8_eap7.md
# Writing openshift to ./example/coolstuff-javaee/openshift.md
# Writing quarkus/springboot to ./example/coolstuff-javaee/quarkus_springboot.md
# We have results from 3 RuleSet(s) in ../data/example_reports/konveyor-examples/example-1/output.yaml
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a> r = report.get_report()
#      <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=13'>14</a> print(f"We have results from {len(r.keys())} RuleSet(s) in {path_to_report}\n")
# ---> <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a> report.write_markdown(output_dir)
#
# /Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb Cell 6 line 5
#      <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=48'>49</a> f.truncate(0)
#      <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=49'>50</a> buffer = StringIO()
# ---> <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=50'>51</a> self._get_markdown_snippet(ruleset_name, buffer)
#      <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=51'>52</a> buffer.seek(0)
#      <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=52'>53</a> shutil.copyfileobj(buffer, f)
#
# /Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb Cell 6 line 6
#      <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=59'>60</a> f.write(f"# {ruleset_name}\n")
#      <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=60'>61</a> f.write(f"## Description\n")
# ---> <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=61'>62</a> f.write(f"{ruleset['description']}\n")
#      <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=62'>63</a> f.write(f"* Source of rules: https://github.com/konveyor/rulesets/tree/main/default/generated/quarkus\n")
#      <a href='vscode-notebook-cell:/Users/jmatthews/git/jwmatthews/kyma_poc/nbs/04_report.ipynb#X20sZmlsZQ%3D%3D?line=63'>64</a> f.write(f"* Sample application: https://github.com/deewhyweb/eap-coolstore-monolith\n")
#
# KeyError: 'description'
