# %% [raw]
# ---
# description: Generative AI POC for code generation
# output-file: index.html
# title: kyma_poc
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# # Prereq
#
# We are currently running against openai.com hosted models.  An API Key from OpenAI.com is required in order to run these examples yourself.  We expect that the shell environment has been configured with the API key exported.
# 1. `export OPENAI_API_KEY="myopenaikeyvaluehere"`
#
# ## Tip
# We are running with the above in our shell config so all of our terminals/environments inherit this.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install kyma_poc
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2

# %% [markdown]
# Using nbdev:  https://nbdev.fast.ai/tutorials/tutorial.html
# Prior to comitting run:  nbdev_prepare
