# %% [raw]
# ---
# output-file: example_python_repl.html
# title: Example of invoking Python REPL
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from langchain.schema.output_parser import StrOutputParser
from langchain_experimental.utilities.python import PythonREPL


def _sanitize_output(text: str):
    _, after = text.split("```python")
    return after.split("```")[0]

template = """Write some python code to solve the user's problem. 

Return only python code in Markdown format, e.g.:

```python
....
```"""
prompt = ChatPromptTemplate.from_messages(
    [("system", template), ("human", "{input}")]
)

model = ChatOpenAI()

chain = prompt | model | StrOutputParser() | _sanitize_output | PythonREPL().run

# %% [markdown]
# Turn debug on so we can see more of what langchain is doing

# %%
from langchain.globals import set_debug
set_debug(True)

# %% [markdown]
# Lets run the chain and see it work

# %%
chain.invoke({"input": "whats 2 plus 2"})
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": "whats 2 plus 2"
# }
# [chain/start] [1:chain:RunnableSequence > 2:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "input": "whats 2 plus 2"
# }
# [chain/end] [1:chain:RunnableSequence > 2:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "SystemMessage"
#         ],
#         "kwargs": {
#           "content": "Write some python code to solve the user's problem. \n\nReturn only python code in Markdown format, e.g.:\n\n```python\n....\n```",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "whats 2 plus 2",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 3:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: Write some python code to solve the user's problem. \n\nReturn only python code in Markdown format, e.g.:\n\n```python\n....\n```\nHuman: whats 2 plus 2"
#   ]
# }
# Python REPL can execute arbitrary code. Use with caution.
# [llm/end] [1:chain:RunnableSequence > 3:llm:ChatOpenAI] [1.27s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "```python\nresult = 2 + 2\nprint(result)\n```",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "```python\nresult = 2 + 2\nprint(result)\n```",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 47,
#       "completion_tokens": 15,
#       "total_tokens": 62
#     },
#     "model_name": "gpt-3.5-turbo"
#   },
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 4:parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 4:parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "```python\nresult = 2 + 2\nprint(result)\n```"
# }
# [chain/start] [1:chain:RunnableSequence > 5:chain:_sanitize_output] Entering Chain run with input:
# {
#   "input": "```python\nresult = 2 + 2\nprint(result)\n```"
# }
# [chain/end] [1:chain:RunnableSequence > 5:chain:_sanitize_output] s] Exiting Chain run with output:
# {
#   "output": "\nresult = 2 + 2\nprint(result)\n"
# }
# [chain/start] [1:chain:RunnableSequence > 6:chain:run] Entering Chain run with input:
# {
#   "input": "\nresult = 2 + 2\nprint(result)\n"
# }
# [chain/end] [1:chain:RunnableSequence > 6:chain:run] s] Exiting Chain run with output:
# {
#   "output": "4\n"
# }
# [chain/end] [1:chain:RunnableSequence] [1.28s] Exiting Chain run with output:
# {
#   "output": "4\n"
# }
# '4\n'
